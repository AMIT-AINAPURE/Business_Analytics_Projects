# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

data = pd.read_csv('C:/Users/Amit/Desktop/Data EDA/1k_sales_Data.csv')

# %%
cdata = data.copy()

# %%
cdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          1000 non-null   object
#  1   Country         1000 non-null   object
#  2   Item Type       1000 non-null   object
#  3   Sales Channel   1000 non-null   object
#  4   Order Priority  1000 non-null   object
#  5   Order Date      1000 non-null   object
#  6   Order ID        1000 non-null   int64
#  7   Ship Date       1000 non-null   object
#  8   Units Sold      1000 non-null   int64
#  9   Unit Price      1000 non-null   float64
#  10  Unit Cost       1000 non-null   float64
#  11  Total Revenue   1000 non-null   float64
#  12  Total Cost      1000 non-null   float64
#  13  Total Profit    1000 non-null   float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 109.5+ KB

# %%
cdata.head()
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M   11/7/2011  185941302   12/8/2011        3018      154.06
# 2              C  10/31/2016  246222341   12/9/2016        1517      255.28
# 3              C   4/10/2010  161442649   5/12/2010        3322      205.70
# 4              H   8/16/2011  645713555   8/31/2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     263.33     3692591.20  2224085.18    1468506.02
# ...

# %%
cdata = cdata.drop('Order Priority',axis=1)
cdata = cdata.drop('Order ID', axis = 1)
cdata.head()
# Out:
#                          Region Country   Item Type Sales Channel  Order Date  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline  10/18/2014
# 1                 North America  Canada  Vegetables        Online   11/7/2011
# 2  Middle East and North Africa   Libya   Baby Food       Offline  10/31/2016
# 3                          Asia   Japan      Cereal       Offline   4/10/2010
# 4            Sub-Saharan Africa    Chad      Fruits       Offline   8/16/2011
#
#     Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 0  10/31/2014        8446      437.20     263.33     3692591.20  2224085.18
# 1   12/8/2011        3018      154.06      90.93      464953.08   274426.74
# 2   12/9/2016        1517      255.28     159.42      387259.76   241840.14
# 3   5/12/2010        3322      205.70     117.11      683335.40   389039.42
# 4   8/31/2011        9845        9.33       6.92       91853.85    68127.40
#
#    Total Profit
# 0    1468506.02
# ...

# %%
cdata.Region.unique()
# Out:
# array(['Middle East and North Africa', 'North America', 'Asia',
#        'Sub-Saharan Africa', 'Europe',
#        'Central America and the Caribbean', 'Australia and Oceania'],
#       dtype=object)

# %%
cdata.Country.count()
# Out:
# 1000

# %%
cdata.isna().sum()
# Out:
# Region           0
# Country          0
# Item Type        0
# Sales Channel    0
# Order Date       0
# Ship Date        0
# Units Sold       0
# Unit Price       0
# Unit Cost        0
# Total Revenue    0
# Total Cost       0
# Total Profit     0
# dtype: int64

# %%
cdata.head()
# Out:
#                          Region Country   Item Type Sales Channel  Order Date  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline  10/18/2014
# 1                 North America  Canada  Vegetables        Online   11/7/2011
# 2  Middle East and North Africa   Libya   Baby Food       Offline  10/31/2016
# 3                          Asia   Japan      Cereal       Offline   4/10/2010
# 4            Sub-Saharan Africa    Chad      Fruits       Offline   8/16/2011
#
#     Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 0  10/31/2014        8446      437.20     263.33     3692591.20  2224085.18
# 1   12/8/2011        3018      154.06      90.93      464953.08   274426.74
# 2   12/9/2016        1517      255.28     159.42      387259.76   241840.14
# 3   5/12/2010        3322      205.70     117.11      683335.40   389039.42
# 4   8/31/2011        9845        9.33       6.92       91853.85    68127.40
#
#    Total Profit
# 0    1468506.02
# ...

# %%
cdata.rename(columns={'Item Type':'ItemType','Sales Channel':'SalesChannel','Units Sold':'UnitsSold','Unit Price':'UnitPrice','Unit Cost':'UnitCost','Total Revenue':'TotalRevenue','Total Cost':'TotalCost','Total Profit':'TotalProfit'},inplace=True)

# %%
cdata.head()
# Out:
#                          Region Country    ItemType SalesChannel  Order Date  \
# 0  Middle East and North Africa   Libya   Cosmetics      Offline  10/18/2014
# 1                 North America  Canada  Vegetables       Online   11/7/2011
# 2  Middle East and North Africa   Libya   Baby Food      Offline  10/31/2016
# 3                          Asia   Japan      Cereal      Offline   4/10/2010
# 4            Sub-Saharan Africa    Chad      Fruits      Offline   8/16/2011
#
#     Ship Date  UnitsSold  UnitPrice  UnitCost  TotalRevenue   TotalCost  \
# 0  10/31/2014       8446     437.20    263.33    3692591.20  2224085.18
# 1   12/8/2011       3018     154.06     90.93     464953.08   274426.74
# 2   12/9/2016       1517     255.28    159.42     387259.76   241840.14
# 3   5/12/2010       3322     205.70    117.11     683335.40   389039.42
# 4   8/31/2011       9845       9.33      6.92      91853.85    68127.40
#
#    TotalProfit
# 0   1468506.02
# 1    190526.34
# 2    145419.62
# ...

# %%
cdata.ItemType.value_counts()
# Out:
# Beverages          101
# Vegetables          97
# Office Supplies     89
# Baby Food           87
# Personal Care       87
# Snacks              82
# Cereal              79
# Meat                78
# Clothes             78
# Household           77
# Cosmetics           75
# Fruits              70
# Name: ItemType, dtype: int64

# %%
cdata.ItemType.value_counts().plot.barh()
plt.show()

# %%
# Now we know that we have sold Beverages the most followed by Vegetablees and least number of fruts have been sold

# %%
cdata.Country.value_counts()
# Out:
# Cuba                              11
# Zimbabwe                          10
# Czech Republic                    10
# Malaysia                          10
# Bahrain                           10
#                                   ..
# Federated States of Micronesia     2
# Kazakhstan                         2
# Cameroon                           1
# Malta                              1
# Kosovo                             1
# Name: Country, Length: 185, dtype: int64

# %%
plt.figure(figsize=(9,9))
cdata.SalesChannel.value_counts().plot.bar()
plt.show()

# %%
# Thus we know that offline sales are higher than online sales than a slight margin

# %%
plt.figure(figsize=(10,10))
cdata.plot.scatter(x='TotalProfit',y='ItemType')
plt.show()

# %%
# from this now we know that we have highest profits for 
# Cosmetics,Househild,Office Supplies and fruits have the least numbers of profits.

# %%
cdata.plot.scatter(x='SalesChannel',y='ItemType')
plt.show()

# %%
cdata['Sales_Channel']= np.where(cdata.SalesChannel=='Offline',1,0)
cdata.Sales_Channel.value_counts()
# Offline = 1 and Online = 0
# Out:
# 1    520
# 0    480
# Name: Sales_Channel, dtype: int64

# %%
plt.figure(figsize=(30,10))
cdata.groupby('ItemType')['Sales_Channel'].mean().plot.bar()
plt.show()

# %%
# this shows that vegitables, house hold items are bought in offline more compared to online
# people prefer to buy cosmetics,cloths,snacks and cereal online

# %%
cdata.head()
# Out:
#                          Region Country    ItemType SalesChannel  Order Date  \
# 0  Middle East and North Africa   Libya   Cosmetics      Offline  10/18/2014
# 1                 North America  Canada  Vegetables       Online   11/7/2011
# 2  Middle East and North Africa   Libya   Baby Food      Offline  10/31/2016
# 3                          Asia   Japan      Cereal      Offline   4/10/2010
# 4            Sub-Saharan Africa    Chad      Fruits      Offline   8/16/2011
#
#     Ship Date  UnitsSold  UnitPrice  UnitCost  TotalRevenue   TotalCost  \
# 0  10/31/2014       8446     437.20    263.33    3692591.20  2224085.18
# 1   12/8/2011       3018     154.06     90.93     464953.08   274426.74
# 2   12/9/2016       1517     255.28    159.42     387259.76   241840.14
# 3   5/12/2010       3322     205.70    117.11     683335.40   389039.42
# 4   8/31/2011       9845       9.33      6.92      91853.85    68127.40
#
#    TotalProfit  Sales_Channel
# 0   1468506.02              1
# ...

# %%
print(cdata[['TotalCost','TotalProfit','ItemType']].corr())
# Out:
#              TotalCost  TotalProfit
# TotalCost     1.000000     0.797041
# TotalProfit   0.797041     1.000000

# %%
sns.pairplot(cdata[['TotalCost','TotalProfit','TotalRevenue']])
plt.show()

# %%
sns.heatmap(cdata[['TotalCost','TotalProfit','TotalRevenue']].corr(),annot=True,cmap='Reds')
plt.show()

# %%
# lets see the corelation matrix of entire dataset

plt.figure(figsize=(9,9))
sns.heatmap(cdata.corr(),annot=True,cmap='Reds')
plt.show()

# %%
cdata.head()
# Out:
#                          Region Country    ItemType SalesChannel  Order Date  \
# 0  Middle East and North Africa   Libya   Cosmetics      Offline  10/18/2014
# 1                 North America  Canada  Vegetables       Online   11/7/2011
# 2  Middle East and North Africa   Libya   Baby Food      Offline  10/31/2016
# 3                          Asia   Japan      Cereal      Offline   4/10/2010
# 4            Sub-Saharan Africa    Chad      Fruits      Offline   8/16/2011
#
#     Ship Date  UnitsSold  UnitPrice  UnitCost  TotalRevenue   TotalCost  \
# 0  10/31/2014       8446     437.20    263.33    3692591.20  2224085.18
# 1   12/8/2011       3018     154.06     90.93     464953.08   274426.74
# 2   12/9/2016       1517     255.28    159.42     387259.76   241840.14
# 3   5/12/2010       3322     205.70    117.11     683335.40   389039.42
# 4   8/31/2011       9845       9.33      6.92      91853.85    68127.40
#
#    TotalProfit  Sales_Channel
# 0   1468506.02              1
# ...

# %%
cdata.groupby('ItemType')['TotalProfit'].mean().plot.bar()
plt.show()

# %%
# Now we know that fruits bevereges and personal carre generate least number of profits

# %%
results = pd.pivot_table(data=cdata,index='Region',columns='ItemType',values='UnitsSold')
print(results)
# Out:
# ItemType                             Baby Food    Beverages       Cereal  \
# Region
# Asia                               4293.076923  4964.705882  4666.857143
# Australia and Oceania              7182.666667  4926.571429  5399.375000
# Central America and the Caribbean  5850.500000  8116.142857  3714.666667
# Europe                             5375.125000  4446.750000  5011.578947
# Middle East and North Africa       3953.076923  4756.133333  4422.090909
# North America                      4056.750000  2315.666667          NaN
# Sub-Saharan Africa                 5314.041667  5267.000000  5383.640000
#
# ItemType                               Clothes    Cosmetics       Fruits  \
# Region
# Asia                               3470.000000  4978.235294  4459.875000
# Australia and Oceania              2836.666667  5031.428571  5990.200000
# Central America and the Caribbean  4499.875000  5870.333333  5911.500000
# ...

# %%
plt.figure(figsize=(30,15))
sns.heatmap(results,annot=True,cmap='RdYlGn')
plt.show()

# %%
# from this now we know that 
# In North America =Household,OfficeSupplies,PersonalCare are sold very much.
# central america and caribbean = Beverages are sold in high numbers
# Australia and Oceania = Office supplies are sold very less here
# North America = Beverages saold in low numbers
